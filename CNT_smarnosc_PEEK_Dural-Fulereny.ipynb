# %% [markdown]
# # CNT a smarność PEEK Dural Fulereny

# %% [markdown]
# ## Import data from file
# Files in folder "Smarnosc_csv_all":
# ### **PEEK Dural**
# - **DCV**
#
# |40T_19|43T_19|45T_19
# |:-:|---|---|
# |2019_7_16_12_40_50|2019_7_16_10_55_22|2019_7_16_11_51_55
# |2019_7_16_13_15_9|2019_7_16_11_12_41|2019_7_16_12_9_34
# |2019_7_16_13_37_3|2019_7_16_11_35_48|2019_7_16_12_24_30
#
#
# |41T_19|44T_19|42T_19
# |:-:|---|---|
# |2019_9_13_10_32_39|2019_9_13_11_5_23|2019_9_13_11_39_43
# 2019_9_13_10_51_24|2019_9_13_11_18_59|2019_9_13_11_52_48
#
#
#
#
#
#
# - **DCI**
#
# |40T_19|43T_19|45T_19|
# |:------:|:------:|:------:|
# |2019_7_22_11_51_40|2019_7_22_12_12_29|2019_7_22_12_25_56
# |2019_7_22_12_37_54|2019_7_22_12_55_8|2019_7_22_13_8_6
# |2019_7_22_13_21_29|
#
# ## DCV 15-19.11.2019
#
# **1 - PAO**
# 2019_11_15_9_37_24
# 2019_11_15_9_52_41
# 2019_11_15_10_10_44
#
# **2 - PAO Fulereny**
# 2019_11_18_13_10_42
# 2019_11_18_13_23_22
# 2019_11_18_13_36_10
#
# **3 - PAO Stadis**
# 2019_11_15_11_1_6
# 2019_11_15_11_25_41
# 2019_11_15_11_40_8
#
# **4 - PAO Fulereny Additin**
# 2019_11_15_11_54_9
# 2019_11_15_12_8_20
#
# **5 - PAO CNT**
# 2019_11_19_7_44_8
# 2019_11_19_7_56_54
# 2019_11_19_8_9_52
#
# **6 - PAO Stadis Additin**
# 2019_11_18_7_52_44
# 2019_11_18_8_7_12
# 2019_11_18_8_21_54
#
# **7 - PAO Stadis CNT Additin**
# 2019_11_19_8_22_13
# 2019_11_19_8_34_41
# 2019_11_19_8_47_28

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
import pandas as pd # primary data structure library

# getting data
def handle_data(data):
    data.drop(['Item' ,'Unnamed: 3'], axis=1,inplace=True)
    data.rename(columns={"Dmm1_Time(s)(1)(1)": "Time", "Dmm1_DcVoltage(1)(1)": "Voltage"},inplace = True)
    data['Voltage']=data['Voltage']*-1000
    
def handle_data2(data):
    data.drop(['Item' ,'Unnamed: 3'], axis=1,inplace=True)
    data.rename(columns={"Dmm1_Time(s)(1)(1)": "Time", "Dmm1_DcVoltage(1)(1)": "Voltage"},inplace = True)
    data['Voltage']=data['Voltage']*1000

df_40T = pd.read_csv(r"Smarnosc_csv_all/2019_7_16_12_40_50.csv",delimiter =';',decimal=",")
handle_data(df_40T)
df_40T2 = pd.read_csv(r"Smarnosc_csv_all/2019_7_16_13_15_9.csv",delimiter =';',decimal=",")
handle_data(df_40T2)
df_40T3 = pd.read_csv(r"Smarnosc_csv_all/2019_7_16_13_37_3.csv",delimiter =';',decimal=",")
handle_data(df_40T3)

df_41T = pd.read_csv(r"Smarnosc_csv_all/2019_9_13_10_32_39.csv",delimiter =';',decimal=",")
handle_data(df_41T)
df_41T2 = pd.read_csv(r"Smarnosc_csv_all/2019_9_13_10_51_24.csv",delimiter =';',decimal=",")
handle_data(df_41T2)
df_41T3 = pd.read_csv(r"Smarnosc_csv_all/2019_9_16_13_6_55.csv",delimiter =';',decimal=",")
handle_data(df_41T3)
df_41T4 = pd.read_csv(r"Smarnosc_csv_all/2019_9_16_13_23_13.csv",delimiter =';',decimal=",")
handle_data(df_41T4)

df_42T = pd.read_csv(r"Smarnosc_csv_all/2019_9_13_11_39_43.csv",delimiter =';',decimal=",")
handle_data(df_42T)
df_42T2 = pd.read_csv(r"Smarnosc_csv_all/2019_9_13_11_52_48.csv",delimiter =';',decimal=",")
handle_data(df_42T2)
df_42T3 = pd.read_csv(r"Smarnosc_csv_all/2019_9_16_11_48_2.csv",delimiter =';',decimal=",")
handle_data(df_42T3)
df_42T4 = pd.read_csv(r"Smarnosc_csv_all/2019_9_16_12_5_30.csv",delimiter =';',decimal=",")
handle_data(df_42T4)
df_42T5 = pd.read_csv(r"Smarnosc_csv_all/2019_9_16_12_23_29.csv",delimiter =';',decimal=",")
handle_data(df_42T5)
df_42T6 = pd.read_csv(r"Smarnosc_csv_all/2019_9_16_12_50_16.csv",delimiter =';',decimal=",")
handle_data(df_42T6)

df_43T = pd.read_csv(r"Smarnosc_csv_all/2019_7_16_10_55_22.csv",delimiter =';',decimal=",")
handle_data(df_43T)
df_43T2 = pd.read_csv(r"Smarnosc_csv_all/2019_7_16_11_12_41.csv",delimiter =';',decimal=",")
handle_data(df_43T2)
df_43T3 = pd.read_csv(r"Smarnosc_csv_all/2019_7_16_11_35_48.csv",delimiter =';',decimal=",")
handle_data(df_43T3)

df_44T = pd.read_csv(r"Smarnosc_csv_all/2019_9_13_11_5_23.csv",delimiter =';',decimal=",")
handle_data(df_44T)
df_44T2 = pd.read_csv(r"Smarnosc_csv_all/2019_9_13_11_18_59.csv",delimiter =';',decimal=",")
handle_data(df_44T2)

df_45T = pd.read_csv(r"Smarnosc_csv_all/2019_7_16_11_51_55.csv",delimiter =';',decimal=",")
handle_data(df_45T)
df_45T2 = pd.read_csv(r"Smarnosc_csv_all/2019_7_16_12_9_34.csv",delimiter =';',decimal=",")
handle_data(df_45T2)
df_45T3 = pd.read_csv(r"Smarnosc_csv_all/2019_7_16_12_24_30.csv",delimiter =';',decimal=",")
handle_data(df_45T3)


df_1A = pd.read_csv(r"Smarnosc_csv_all/2019_11_15_9_37_24.csv",delimiter =';',decimal=",")
handle_data2(df_1A)
df_1B = pd.read_csv(r"Smarnosc_csv_all/2019_11_15_9_52_41.csv",delimiter =';',decimal=",")
handle_data2(df_1B)
df_1C = pd.read_csv(r"Smarnosc_csv_all/2019_11_15_10_10_44.csv",delimiter =';',decimal=",")
handle_data2(df_1C)

df_2A = pd.read_csv(r"Smarnosc_csv_all/2019_11_18_13_10_42.csv",delimiter =';',decimal=",")
handle_data2(df_2A)
df_2B = pd.read_csv(r"Smarnosc_csv_all/2019_11_18_13_23_22.csv",delimiter =';',decimal=",")
handle_data2(df_2B)
df_2C = pd.read_csv(r"Smarnosc_csv_all/2019_11_18_13_36_10.csv",delimiter =';',decimal=",")
handle_data2(df_2C)

df_3A = pd.read_csv(r"Smarnosc_csv_all/2019_11_15_11_1_6.csv",delimiter =';',decimal=",")
handle_data2(df_3A)
df_3B = pd.read_csv(r"Smarnosc_csv_all/2019_11_15_11_25_41.csv",delimiter =';',decimal=",")
handle_data2(df_3B)
df_3C = pd.read_csv(r"Smarnosc_csv_all/2019_11_15_11_40_8.csv",delimiter =';',decimal=",")
handle_data2(df_3C)

df_4A = pd.read_csv(r"Smarnosc_csv_all/2019_11_15_11_54_9.csv",delimiter =';',decimal=",")
handle_data2(df_4A)
df_4B = pd.read_csv(r"Smarnosc_csv_all/2019_11_15_12_8_20.csv",delimiter =';',decimal=",")
handle_data2(df_4B)

df_5A = pd.read_csv(r"Smarnosc_csv_all/2019_11_19_7_44_8.csv",delimiter =';',decimal=",")
handle_data2(df_5A)
df_5B = pd.read_csv(r"Smarnosc_csv_all/2019_11_19_7_56_54.csv",delimiter =';',decimal=",")
handle_data2(df_5B)
df_5C = pd.read_csv(r"Smarnosc_csv_all/2019_11_19_8_9_52.csv",delimiter =';',decimal=",")
handle_data2(df_5C)

df_6A = pd.read_csv(r"Smarnosc_csv_all/2019_11_18_7_52_44.csv",delimiter =';',decimal=",")
handle_data2(df_6A)
df_6B = pd.read_csv(r"Smarnosc_csv_all/2019_11_18_8_7_12.csv",delimiter =';',decimal=",")
handle_data2(df_6B)
df_6C = pd.read_csv(r"Smarnosc_csv_all/2019_11_18_8_21_54.csv",delimiter =';',decimal=",")
handle_data2(df_6C)

df_7A = pd.read_csv(r"Smarnosc_csv_all/2019_11_19_8_22_13.csv",delimiter =';',decimal=",")
handle_data2(df_7A)
df_7B = pd.read_csv(r"Smarnosc_csv_all/2019_11_19_8_34_41.csv",delimiter =';',decimal=",")
handle_data2(df_7B)
df_7C = pd.read_csv(r"Smarnosc_csv_all/2019_11_19_8_47_28.csv",delimiter =';',decimal=",")
handle_data2(df_7C)

df_1AA = pd.read_csv(r"Smarnosc_csv_all/2019_11_26_8_56_32.csv",delimiter =';',decimal=",")
handle_data(df_1AA)
df_1BB = pd.read_csv(r"Smarnosc_csv_all/2019_11_26_9_14_46.csv",delimiter =';',decimal=",")
handle_data(df_1BB)
df_1CC = pd.read_csv(r"Smarnosc_csv_all/2019_11_26_9_32_17.csv",delimiter =';',decimal=",")
handle_data(df_1CC)
df_1DD = pd.read_csv(r"Smarnosc_csv_all/2019_11_26_9_58_27.csv",delimiter =';',decimal=",")
handle_data(df_1DD)

df_7AA = pd.read_csv(r"Smarnosc_csv_all/2019_11_26_11_38_26.csv",delimiter =';',decimal=",")
handle_data(df_7AA)
df_7BB = pd.read_csv(r"Smarnosc_csv_all/2019_11_26_11_52_43.csv",delimiter =';',decimal=",")
handle_data(df_7BB)
df_7CC = pd.read_csv(r"Smarnosc_csv_all/2019_11_26_12_8_55.csv",delimiter =';',decimal=",")
handle_data(df_7CC)

df_2AA = pd.read_csv(r"Smarnosc_csv_all/2019_11_27_10_13_55.csv",delimiter =';',decimal=",")
handle_data(df_2AA)
df_2BB = pd.read_csv(r"Smarnosc_csv_all/2019_11_27_10_29_25.csv",delimiter =';',decimal=",")
handle_data(df_2BB)
df_2CC = pd.read_csv(r"Smarnosc_csv_all/2019_11_27_10_43_53.csv",delimiter =';',decimal=",")
handle_data(df_2CC)

df_3AA = pd.read_csv(r"Smarnosc_csv_all/2019_11_27_11_45_37.csv",delimiter =';',decimal=",")
handle_data(df_3AA)
df_3BB = pd.read_csv(r"Smarnosc_csv_all/2019_11_27_12_0_36.csv",delimiter =';',decimal=",")
handle_data(df_3BB)
df_3CC = pd.read_csv(r"Smarnosc_csv_all/2019_11_27_12_15_52.csv",delimiter =';',decimal=",")
handle_data(df_3CC)

df_4AA = pd.read_csv(r"Smarnosc_csv_all/2019_11_28_9_10_42.csv",delimiter =';',decimal=",")
handle_data(df_4AA)
df_4BB = pd.read_csv(r"Smarnosc_csv_all/2019_11_28_9_26_11.csv",delimiter =';',decimal=",")
handle_data(df_4BB)
df_4CC = pd.read_csv(r"Smarnosc_csv_all/2019_11_28_9_40_19.csv",delimiter =';',decimal=",")
handle_data(df_4CC)
df_4DD = pd.read_csv(r"Smarnosc_csv_all/2019_11_29_13_10_28.csv",delimiter =';',decimal=",")
handle_data(df_4DD)

df_5AA = pd.read_csv(r"Smarnosc_csv_all/2019_11_29_9_9_7.csv",delimiter =';',decimal=",")
handle_data(df_5AA)
df_5BB = pd.read_csv(r"Smarnosc_csv_all/2019_11_29_9_24_17.csv",delimiter =';',decimal=",")
handle_data(df_5BB)
df_5CC = pd.read_csv(r"Smarnosc_csv_all/2019_11_29_9_38_17.csv",delimiter =';',decimal=",")
handle_data(df_5CC)

df_6AA = pd.read_csv(r"Smarnosc_csv_all/2019_11_29_10_45_1.csv",delimiter =';',decimal=",")
handle_data(df_6AA)
df_6BB = pd.read_csv(r"Smarnosc_csv_all/2019_11_29_10_59_53.csv",delimiter =';',decimal=",")
handle_data(df_6BB)
df_6CC = pd.read_csv(r"Smarnosc_csv_all/2019_11_29_11_15_30.csv",delimiter =';',decimal=",")
handle_data(df_6CC)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-deep')

fig = plt.figure()
fig.set_figheight(8)
fig.set_figwidth(12)

def applyPlotStyle(arg):
    plt.xlabel('Time [s]',fontsize=16)
    plt.ylabel('Voltage [mV]',fontsize=16)
    plt.legend(fontsize=16, markerscale=8)
    plt.tight_layout()
    if arg == 1:
        plt.xlim(0, )
        plt.ylim(min_y, max_y)
    else:
#         plt.xlim(0, )
        plt.xlim(23,25)
        plt.ylim(-10, 20)

def get_df_name(df):
    name = ""
    name =[x for x in globals() if globals()[x] is df][0]
    if name =="df_40T" or name =="df_40T2" or name =="df_40T3"\
    or name =="df_1AA" or name =="df_1BB" or name =="df_1CC" or name =="df_1DD":
        label_name="PAO 8"
    elif name =="df_41T" or name =="df_41T2":
        label_name="PAO8+1,5%ZDDP"
    elif name =="df_42T" or name =="df_42T2" or name =="df_5AA" or name =="df_5BB" or name =="df_5CC":
        label_name="PAO8+0,005%CNT (homogenizer)"    
    elif name =="df_43T" or name =="df_43T2" or name =="df_43T3":
        label_name="PAO8+1,5%ZDDP+0,005%CNT (homogenizer)"
    elif name =="df_44T" or name =="df_44T2":
        label_name="PAO8+1,5%ZDDP+6ppm Stadis"
    elif name =="df_45T" or name =="df_45T2" or name =="df_45T3" \
    or name =="df_7AA" or name =="df_7BB" or name =="df_7CC":
        label_name="PAO8+1,5%ZDDP+0,005%CNT+6ppm Stadis (homogenizer)"
    elif name =="df_2AA" or name =="df_2BB" or name =="df_2CC":
        label_name="PAO8+0,005% C60-C70"
    elif name =="df_3AA" or name =="df_3BB" or name =="df_3CC":
        label_name="PAO8+6ppm Stadis"
    elif name =="df_4AA" or name =="df_4BB" or name =="df_4CC" or name =="df_4DD":
        label_name="PAO8+0,005% C60-C70+1,5%ZDDP"
    elif name =="df_6AA" or name =="df_6BB" or name =="df_6CC":
        label_name="PAO8+6ppm Stadis+1,5%ZDDP"
    else:
        label_name="other"
    return label_name

def scatter_plot(data,**kwargs):
    data_name = get_df_name(data)
    mask = dict(marker='.', s=10)
    plt.scatter(data.Time,data.Voltage, label=data_name,**kwargs, **mask)
    plt.plot(data.Time,data.Voltage,label='_nolegend_',**kwargs)
    applyPlotStyle(2)
    

# #scatter_plot(df_41T, alpha=0.7, zorder=3)
# scatter_plot(df_44T, alpha=0.7, zorder=2)
# scatter_plot(df_44T2, alpha=0.7, zorder=1)
# #scatter_plot(df_45T, alpha=1.0, zorder=1)

# scatter_plot(df_40T, alpha=1, zorder=2)
# scatter_plot(df_40T2, alpha=1, zorder=1)
# scatter_plot(df_40T3, alpha=1, zorder=1)

# scatter_plot(df_41T, alpha=0.7, zorder=5)
# hist_plot(df_41T2, alpha=0.7, zorder=3)
# hist_plot(df_41T3, alpha=0.7, zorder=3)
# hist_plot(df_41T4, alpha=0.7, zorder=3)

# hist_plot(df_42T, alpha=0.6, zorder=2)
# hist_plot(df_42T2, alpha=1, zorder=1)
# hist_plot(df_42T3, alpha=0.7, zorder=1)
# hist_plot(df_42T4, alpha=0.7, zorder=1)
# hist_plot(df_42T5, alpha=0.7, zorder=1)
# hist_plot(df_42T6, alpha=0.7, zorder=1)

# scatter_plot(df_43T, alpha=0.7, zorder=3)
# scatter_plot(df_43T2, alpha=0.7, zorder=2)
# scatter_plot(df_43T3, alpha=1, zorder=1)

# hist_plot(df_44T, alpha=1, zorder=3)
# hist_plot(df_44T2, alpha=0.7, zorder=5)

# hist_plot(df_45T, alpha=0.7, zorder=3)
# hist_plot(df_45T2, alpha=0.7, zorder=2)
# hist_plot(df_45T3, alpha=1, zorder=1)

scatter_plot(df_1AA, alpha=1, zorder=1)
# scatter_plot(df_1BB, alpha=1, zorder=1)
# scatter_plot(df_1CC, alpha=1, zorder=1)
# scatter_plot(df_1DD, alpha=1, zorder=1)

# scatter_plot(df_2AA, alpha=1, zorder=1)
# scatter_plot(df_2BB, alpha=1, zorder=1)
# scatter_plot(df_2CC, alpha=1, zorder=1)

# scatter_plot(df_3AA, alpha=1, zorder=1)
# scatter_plot(df_3BB, alpha=1, zorder=1)
# scatter_plot(df_3CC, alpha=1, zorder=1)

# scatter_plot(df_4BB, alpha=0.7, zorder=1)
# scatter_plot(df_4CC, alpha=0.7, zorder=1)
# scatter_plot(df_4DD, alpha=0.7, zorder=1)

# scatter_plot(df_5AA, alpha=0.7, zorder=1)
# scatter_plot(df_5BB, alpha=0.7, zorder=1)
# scatter_plot(df_5CC, alpha=0.7, zorder=1)

# scatter_plot(df_6AA, alpha=0.7, zorder=1)
# scatter_plot(df_6BB, alpha=0.7, zorder=1)
# scatter_plot(df_6CC, alpha=0.7, zorder=1)

# scatter_plot(df_7AA, alpha=0.7, zorder=1)
# scatter_plot(df_7BB, alpha=0.7, zorder=1)
# scatter_plot(df_7CC, alpha=0.7, zorder=1)

plt.title("PEEK Dural DCV",fontsize=18)
plt.tick_params(axis='both', which='major', labelsize=14)


# plt.savefig("PEEK Dural DCV 4 short.png", bbox_inches='tight',dpi=300)
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-deep')
#plt.style.use("classic")
#plt.style.use("fast")

import toolz

fig = plt.figure()
fig.set_figheight(8)
fig.set_figwidth(12)

def applyPlotStyle(arg):
    plt.xlabel('Time [s]',fontsize=16)
    plt.ylabel('Voltage [mV]',fontsize=16)
    plt.legend(fontsize=16, markerscale=8)
    plt.tight_layout()
    if arg == 1:
        plt.xlim(0, )
        plt.ylim(min_y, max_y)
    else:
        plt.xlim(0, )
        plt.ylim(-50, 400)

def get_df_name(df):
    name = ""
    name =[x for x in globals() if globals()[x] is df][0]
    if name =="df_40T" or name =="df_40T2" or name =="df_40T3"\
    or name =="df_1AA" or name =="df_1BB" or name =="df_1CC" or name =="df_1DD":
        label_name="PAO 8"
    elif name =="df_41T" or name =="df_41T2":
        label_name="PAO8+1,5%ZDDP"
    elif name =="df_42T" or name =="df_42T2" or name =="df_5AA" or name =="df_5BB" or name =="df_5CC":
        label_name="PAO8+0,005%CNT (homogenizer)"    
    elif name =="df_43T" or name =="df_43T2" or name =="df_43T3":
        label_name="PAO8+1,5%ZDDP+0,005%CNT (homogenizer)"
    elif name =="df_44T" or name =="df_44T2":
        label_name="PAO8+1,5%ZDDP+6ppm Stadis"
    elif name =="df_45T" or name =="df_45T2" or name =="df_45T3" \
    or name =="df_7AA" or name =="df_7BB" or name =="df_7CC":
        label_name="PAO8+1,5%ZDDP+0,005%CNT+6ppm Stadis (homogenizer)"
    elif name =="df_2AA" or name =="df_2BB" or name =="df_2CC":
        label_name="PAO8+0,005% C60-C70"
    elif name =="df_3AA" or name =="df_3BB" or name =="df_3CC":
        label_name="PAO8+6ppm Stadis"
    elif name =="df_4AA" or name =="df_4BB" or name =="df_4CC" or name =="df_4DD":
        label_name="PAO8+0,005% C60-C70+1,5%ZDDP"
    elif name =="df_6AA" or name =="df_6BB" or name =="df_6CC":
        label_name="PAO8+6ppm Stadis+1,5%ZDDP"
    else:
        label_name="other"
    return label_name

def scatter_plot(data,**kwargs):
    data_name = get_df_name(data)
    mask = dict(marker='.', s=10)
    plt.scatter(data.Time,data.Voltage, label=data_name,**kwargs, **mask)
    applyPlotStyle(2)
    
# scatter_plot(df_40T, alpha=0.6, zorder=3)
# scatter_plot(df_43T, alpha=0.7, zorder=2)
# scatter_plot(df_45T, alpha=1.0, zorder=1)

def part(data):
    part_data_min=[min(sublist) for sublist in toolz.partition_all(100, data)]
    part_data_max=[max(sublist) for sublist in toolz.partition_all(100, data)]
    return part_data_min, part_data_max

def fill_plot(data,**kwargs):
    data_name = ""
    data_name = get_df_name(data)
    time = part(data.Time)
    y11, y22 = part(data.Voltage)
    plt.fill_between(time[0], y11, y22, label=data_name, edgecolor='black', **kwargs)
    applyPlotStyle(2)

# fill_plot(df_40T, alpha=0.6, zorder=1)
# fill_plot(df_40T2, alpha=0.6, zorder=2)
# fill_plot(df_40T3, alpha=0.6, zorder=3)

# fill_plot(df_41T, alpha=0.7, zorder=1)
# fill_plot(df_41T2, alpha=0.7, zorder=1)

# fill_plot(df_42T, alpha=0.7, zorder=3)
# fill_plot(df_42T2, alpha=0.7, zorder=4)

# fill_plot(df_43T, alpha=1, zorder=3)
# fill_plot(df_43T2, alpha=1, zorder=2)
# fill_plot(df_43T3, alpha=1, zorder=1)

# # fill_plot(df_44T, alpha=0.7, zorder=2)
# # fill_plot(df_44T2, alpha=0.7, zorder=2)

# # fill_plot(df_45T, alpha=0.7, zorder=1)

# fill_plot(df_40T, alpha=1, zorder=2)
# fill_plot(df_40T2, alpha=1, zorder=1)
# fill_plot(df_40T3, alpha=1, zorder=1)

# hist_plot(df_41T, alpha=0.7, zorder=5)
# hist_plot(df_41T2, alpha=0.7, zorder=3)
# hist_plot(df_41T3, alpha=0.7, zorder=3)
# hist_plot(df_41T4, alpha=0.7, zorder=3)

# hist_plot(df_42T, alpha=0.6, zorder=2)
# hist_plot(df_42T2, alpha=1, zorder=1)
# hist_plot(df_42T3, alpha=0.7, zorder=1)
# hist_plot(df_42T4, alpha=0.7, zorder=1)
# hist_plot(df_42T5, alpha=0.7, zorder=1)
# hist_plot(df_42T6, alpha=0.7, zorder=1)

# hist_plot(df_43T, alpha=0.7, zorder=3)
# hist_plot(df_43T2, alpha=0.7, zorder=2)
# hist_plot(df_43T3, alpha=1, zorder=1)

# hist_plot(df_44T, alpha=1, zorder=3)
# hist_plot(df_44T2, alpha=0.7, zorder=5)

# hist_plot(df_45T, alpha=0.7, zorder=3)
# hist_plot(df_45T2, alpha=0.7, zorder=2)
# hist_plot(df_45T3, alpha=1, zorder=1)

# fill_plot(df_1AA, alpha=0.7, zorder=1)
# fill_plot(df_1BB, alpha=0.7, zorder=2)
# fill_plot(df_1CC, alpha=0.7, zorder=3)
# fill_plot(df_1DD, alpha=0.7, zorder=4)

# fill_plot(df_2AA, alpha=0.7, zorder=2)
# fill_plot(df_2BB, alpha=0.7, zorder=1)
# fill_plot(df_2CC, alpha=0.7, zorder=3)

# fill_plot(df_3AA, alpha=0.7, zorder=1)
# fill_plot(df_3BB, alpha=0.7, zorder=1)
# fill_plot(df_3CC, alpha=0.7, zorder=1)

# fill_plot(df_4AA, alpha=0.7, zorder=1)
fill_plot(df_4BB, alpha=0.7, zorder=2)
fill_plot(df_4CC, alpha=0.7, zorder=2)
fill_plot(df_4DD, alpha=0.7, zorder=1)

# fill_plot(df_5AA, alpha=0.7, zorder=1)
# fill_plot(df_5BB, alpha=0.7, zorder=1)
# fill_plot(df_5CC, alpha=0.7, zorder=1)

# fill_plot(df_6AA, alpha=0.7, zorder=2)
# fill_plot(df_6BB, alpha=0.7, zorder=1)
# fill_plot(df_6CC, alpha=0.7, zorder=3)

# fill_plot(df_7AA, alpha=1, zorder=1)
# fill_plot(df_7BB, alpha=0.5, zorder=1)
# fill_plot(df_7CC, alpha=0.5, zorder=1)

plt.title("PEEK Dural DCV",fontsize=18)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc='upper right',fontsize=16)


plt.savefig("PEEK Dural DCV filled 28 11 2019 PAO_4.png", bbox_inches='tight',dpi=300)
plt.show()

# %%
import numpy as np
from matplotlib import gridspec
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-deep')

fig = plt.figure()
gs = gridspec.GridSpec(3, 1)
fig.set_figheight(12)
fig.set_figwidth(12)
#fig.suptitle('DCV PEEK_Dural', fontsize=26)


# ax31 = fig.add_subplot(gs[0,:]) # hist_plot
# hist_plot(df_40T, alpha=1, zorder=2)
# hist_plot(df_41T, alpha=0.7, zorder=3)
# hist_plot(df_41T2, alpha=0.7, zorder=3)
# hist_plot(df_41T3, alpha=0.7, zorder=3)
# hist_plot(df_41T4, alpha=0.7, zorder=3)

# ax32 = fig.add_subplot(gs[1,:]) # scatter_plot
# scatter_plot(df_40T, alpha=1, zorder=2)
# scatter_plot(df_41T, alpha=0.7, zorder=3)
# scatter_plot(df_41T2, alpha=0.7, zorder=3)
# scatter_plot(df_41T3, alpha=0.7, zorder=3)
# scatter_plot(df_41T4, alpha=0.7, zorder=3)

ax1 = fig.add_subplot(gs[2,:])
# fill_plot(df_40T, alpha=1, zorder=20) # PAO
# # fill_plot(df_41T, alpha=0.7, zorder=15) # PAO + ZDDP
# fill_plot(df_42T, alpha=0.7, zorder=2) # PAO + CNT
# fill_plot(df_43T3, alpha=0.7, zorder=12) # PAO + ZDDP + CNT
# # fill_plot(df_44T2, alpha=0.7, zorder=11) # PAO + ZDDP + Stadis
# fill_plot(df_45T, alpha=0.7, zorder=1) # PAO + ZDDP + CNT + Stadis


# PAO
# fill_plot(df_40T, alpha=1, zorder=4) # OK 110mV  <-----
# fill_plot(df_40T2, alpha=1, zorder=1)
# fill_plot(df_40T3, alpha=1, zorder=12)

# PAO + ZDDP 
# hist_plot(df_41T, alpha=0.7, zorder=5) # 150 mV <-------
# hist_plot(df_41T2, alpha=0.7, zorder=3) # 280 mV
# hist_plot(df_41T3, alpha=0.7, zorder=3) # 40 mV
# hist_plot(df_41T4, alpha=0.7, zorder=3) # -20 mV

# PAO + CNT
# fill_plot(df_42T, alpha=0.6, zorder=2) # 200 mV  <-----
# fill_plot(df_42T2, alpha=1, zorder=10) # 100 mV
# # fill_plot(df_42T3, alpha=0.7, zorder=1) # 10 mV
# fill_plot(df_42T4, alpha=0.7, zorder=1) # -50 mV
# fill_plot(df_42T5, alpha=0.7, zorder=1) # -60 mV
# fill_plot(df_42T6, alpha=0.7, zorder=1) # - 60 mV

# PAO + ZDDP + CNT
# hist_plot(df_43T, alpha=0.7, zorder=3) # 120 mV
# hist_plot(df_43T2, alpha=0.7, zorder=2) # 140 mV
# hist_plot(df_43T3, alpha=1, zorder=1) # 200 mV <-----

# PAO + ZDDP + Stadis
# hist_plot(df_44T, alpha=1, zorder=3) # 140 mV 
# hist_plot(df_44T2, alpha=0.7, zorder=5) # 175 mV <-------

# PAO + ZDDP + CNT + Stadis
# hist_plot(df_45T, alpha=0.7, zorder=3) # 300 mV <------
# hist_plot(df_45T2, alpha=0.7, zorder=2) # 200 mV
# hist_plot(df_45T3, alpha=1, zorder=1) # 380 mV

# 1 PAO 
fill_plot(df_1A, alpha=1, zorder=1) # 80 mV <------
fill_plot(df_1B, alpha=0.7, zorder=2) # 45 mV
fill_plot(df_1C, alpha=0.7, zorder=3) # 60 mV

#plt.savefig("PEEK Dural DCI.png", bbox_inches='tight',dpi=600)
plt.show()

# %%
df_3AA.head()
# Out:
#        Time   Voltage
# 0  0.000000  0.005272
# 1  0.020970  0.008445
# 2  0.041933  0.006854
# 3  0.062901  0.007802
# 4  0.106408  0.012371

# %%
import numpy as np
df_1AAX=df_1AA.groupby(np.arange(len(df_1AA))//39).mean()
df_1BBX=df_1BB.groupby(np.arange(len(df_1BB))//39).mean()
df_1CCX=df_1CC.groupby(np.arange(len(df_1CC))//39).mean()
df_1X=(df_1AAX.Voltage+df_1BBX.Voltage+df_1CCX.Voltage)/3

df_2AAX=df_2AA.groupby(np.arange(len(df_2AA))//39).mean()
df_2BBX=df_2BB.groupby(np.arange(len(df_2BB))//39).mean()
df_2CCX=df_2CC.groupby(np.arange(len(df_2CC))//39).mean()
df_2X=(df_2AAX.Voltage+df_2BBX.Voltage+df_2CCX.Voltage)/3

df_3AAX=df_3AA.groupby(np.arange(len(df_3AA))//39).mean()
df_3BBX=df_3BB.groupby(np.arange(len(df_3BB))//39).mean()
df_3CCX=df_3CC.groupby(np.arange(len(df_3CC))//39).mean()
df_3X=(df_3AAX.Voltage+df_3BBX.Voltage+df_3CCX.Voltage)/3

df_4BBX=df_4BB.groupby(np.arange(len(df_4BB))//39).mean()
df_4CCX=df_4CC.groupby(np.arange(len(df_4CC))//39).mean()
df_4DDX=df_4DD.groupby(np.arange(len(df_4DD))//39).mean()
df_4X=(df_4BBX.Voltage+df_4CCX.Voltage+df_4DDX.Voltage)/3

df_5AAX=df_5AA.groupby(np.arange(len(df_5AA))//39).mean()
df_5BBX=df_5BB.groupby(np.arange(len(df_5BB))//39).mean()
df_5CCX=df_5CC.groupby(np.arange(len(df_5CC))//39).mean()
df_5X=(df_5AAX.Voltage+df_5BBX.Voltage+df_5CCX.Voltage)/3

df_6AAX=df_6AA.groupby(np.arange(len(df_6AA))//39).mean()
df_6BBX=df_6BB.groupby(np.arange(len(df_6BB))//39).mean()
df_6CCX=df_6CC.groupby(np.arange(len(df_6CC))//39).mean()
df_6X=(df_6AAX.Voltage+df_6BBX.Voltage+df_6CCX.Voltage)/3

df_7AAX=df_7AA.groupby(np.arange(len(df_7AA))//39).mean()
df_7BBX=df_7BB.groupby(np.arange(len(df_7BB))//39).mean()
df_7CCX=df_7CC.groupby(np.arange(len(df_7CC))//39).mean()
df_7X=(df_7AAX.Voltage+df_7BBX.Voltage+df_7CCX.Voltage)/3

df_41TX=df_41T.groupby(np.arange(len(df_41T))//39).mean()
df_41T2X=df_41T2.groupby(np.arange(len(df_41T2))//39).mean()
df_41X=(df_41TX.Voltage+df_41T2X.Voltage)/2

df_43TX=df_43T.groupby(np.arange(len(df_43T))//39).mean()
df_43T2X=df_43T2.groupby(np.arange(len(df_43T2))//39).mean()
df_43T3X=df_43T3.groupby(np.arange(len(df_43T3))//39).mean()
df_43X=(df_43T3X.Voltage)/1

# %%
df_1X = df_1X.to_frame()
df_1X.insert(loc=0, column='Time', value=np.arange(len(df_1X)))

df_2X = df_2X.to_frame()
df_2X.insert(loc=0, column='Time', value=np.arange(len(df_2X)))

df_3X = df_3X.to_frame()
df_3X.insert(loc=0, column='Time', value=np.arange(len(df_3X)))

df_4X = df_4X.to_frame()
df_4X.insert(loc=0, column='Time', value=np.arange(len(df_4X)))

df_5X = df_5X.to_frame()
df_5X.insert(loc=0, column='Time', value=np.arange(len(df_5X)))

df_6X = df_6X.to_frame()
df_6X.insert(loc=0, column='Time', value=np.arange(len(df_6X)))

df_7X = df_7X.to_frame()
df_7X.insert(loc=0, column='Time', value=np.arange(len(df_7X)))

df_41X = df_41X.to_frame()
df_41X.insert(loc=0, column='Time', value=np.arange(len(df_41X)))

df_43X = df_43X.to_frame()
df_43X.insert(loc=0, column='Time', value=np.arange(len(df_43X)))
# df_1X.head()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-deep')

fig = plt.figure()
fig.set_figheight(8)
fig.set_figwidth(12)

def applyPlotStyle(arg):
    plt.xlabel('Time [s]',fontsize=16)
    plt.ylabel('Voltage [mV]',fontsize=16)
    plt.legend(fontsize=16, markerscale=8)
    plt.tight_layout()
    if arg == 1:
        plt.xlim(0, )
        plt.ylim(min_y, max_y)
    else:
        plt.xlim(0,200)
#         plt.xlim(540,542)
        plt.ylim(-0, 50)

def get_df_name(df):
    name = ""
    name =[x for x in globals() if globals()[x] is df][0]
    if name =="df_40T" or name =="df_40T2" or name =="df_40T3"\
    or name =="df_1AA" or name =="df_1BB" or name =="df_1CC" or name =="df_1DD" or name =="df_1X":
        label_name="PAO 8"
    elif name =="df_41T" or name =="df_41T2" or name =="df_41X":
        label_name="PAO8+1,5%ZDDP"
    elif name =="df_42T" or name =="df_42T2" \
    or name =="df_5AA" or name =="df_5BB" or name =="df_5CC" or name =="df_5X":
        label_name="PAO8+0,005%CNT (homogenizer)"    
    elif name =="df_43T" or name =="df_43T2" or name =="df_43T3" or name =="df_43X":
        label_name="PAO8+1,5%ZDDP+0,005%CNT (homogenizer)"
    elif name =="df_44T" or name =="df_44T2":
        label_name="PAO8+1,5%ZDDP+6ppm Stadis"
    elif name =="df_45T" or name =="df_45T2" or name =="df_45T3" \
    or name =="df_7AA" or name =="df_7BB" or name =="df_7CC" or name =="df_7X":
        label_name="PAO8+1,5%ZDDP+0,005%CNT+6ppm Stadis (homogenizer)"
    elif name =="df_2AA" or name =="df_2BB" or name =="df_2CC" or name =="df_2X":
        label_name="PAO8+0,005% C60-C70"
    elif name =="df_3AA" or name =="df_3BB" or name =="df_3CC" or name =="df_3X":
        label_name="PAO8+6ppm Stadis"
    elif name =="df_4AA" or name =="df_4BB" or name =="df_4CC" or name =="df_4DD" or name =="df_4X":
        label_name="PAO8+0,005% C60-C70+1,5%ZDDP"
    elif name =="df_6AA" or name =="df_6BB" or name =="df_6CC" or name =="df_6X":
        label_name="PAO8+6ppm Stadis+1,5%ZDDP"
    else:
        label_name="other"
    return label_name

def scatter_plot(data,**kwargs):
    data_name = get_df_name(data)
    mask = dict(marker='.', s=10)
    plt.scatter(data.Time,data.Voltage, label=data_name,**kwargs, **mask)
    plt.plot(data.Time,data.Voltage,label='_nolegend_',**kwargs)
    applyPlotStyle(2)



# scatter_plot(df_1X, alpha=0.7, zorder=1, color='red')
# scatter_plot(df_2X, alpha=0.7, zorder=1, color='black')
# scatter_plot(df_3X, alpha=0.7, zorder=1, color='blue')
# scatter_plot(df_4X, alpha=0.7, zorder=2, color='black')
# scatter_plot(df_5X, alpha=0.7, zorder=2, color='green')
scatter_plot(df_6X, alpha=0.7, zorder=1, color='green')
scatter_plot(df_7X, alpha=0.7, zorder=1, color='blue')

# scatter_plot(df_41X, alpha=0.7, zorder=1, color='magenta')
# scatter_plot(df_43X, alpha=0.7, zorder=1, color='green')


plt.title("PEEK Dural DCV",fontsize=18)
plt.tick_params(axis='both', which='major', labelsize=14)


plt.savefig("PEEK Dural DCV avrage_3.png", bbox_inches='tight',dpi=300)
plt.show()

# %%
def wieksze_niz (data):
    data.Time = data.Time.round(0)
    data = data[data.Voltage > 1]
    data = data.groupby("Time").sum()
    return data   

def concat(df_1,df_2,df_3):
    df_1=wieksze_niz (df_1)
    df_2=wieksze_niz (df_2)
    df_3=wieksze_niz (df_3)
    resultY=(pd.concat([df_1,df_2,df_3], sort=False, join='outer').groupby('Time')['Voltage']\
        .sum().reset_index())
    resultY.Voltage=resultY.Voltage/3
    return resultY

df_1Y=concat(df_1AA,df_1BB,df_1CC)
df_2Y=concat(df_2AA,df_2BB,df_2CC)
df_3Y=concat(df_3AA,df_3BB,df_3CC)
df_4Y=concat(df_4BB,df_4CC,df_4DD)
df_5Y=concat(df_5AA,df_5BB,df_5CC)
df_6Y=concat(df_6AA,df_6BB,df_6CC)
df_7Y=concat(df_7AA,df_7BB,df_7CC)
df_41Y=concat(df_41T,df_41T2,df_41T3)
df_43Y=concat(df_43T3,df_43T3,df_43T3)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-deep')

fig = plt.figure()
fig.set_figheight(8)
fig.set_figwidth(12)

x1=1400

plt.text(201, x1, "ŚR"+" $\pm$ "+"ODCH. STD.", verticalalignment='bottom', horizontalalignment='left',
        color="black", fontsize=16)

def applyPlotStyle(arg):
    plt.xlabel('Time [s]',fontsize=16)
    plt.ylabel('Voltage [mV]',fontsize=16)
    plt.legend(fontsize=16, markerscale=8)
    plt.tight_layout()
    if arg == 1:
        plt.xlim(0, )
        plt.ylim(min_y, max_y)
    else:
        plt.xlim(0,200)
#         plt.xlim(540,542)
        plt.ylim(-20,1600 )

def get_df_name(df):
    name = ""
    name =[x for x in globals() if globals()[x] is df][0]
    if name =="df_40T" or name =="df_40T2" or name =="df_40T3"\
    or name =="df_1AA" or name =="df_1BB" or name =="df_1CC" or name =="df_1DD" or name =="df_1Y":
        label_name="PAO 8"
    elif name =="df_41T" or name =="df_41T2" or name =="df_41Y":
        label_name="PAO8+1,5%ZDDP"
    elif name =="df_42T" or name =="df_42T2" \
    or name =="df_5AA" or name =="df_5BB" or name =="df_5CC" or name =="df_5Y":
        label_name="PAO8+0,005%CNT (homogenizer)"    
    elif name =="df_43T" or name =="df_43T2" or name =="df_43T3" or name =="df_43Y":
        label_name="PAO8+1,5%ZDDP+0,005%CNT (homogenizer)"
    elif name =="df_44T" or name =="df_44T2":
        label_name="PAO8+1,5%ZDDP+6ppm Stadis"
    elif name =="df_45T" or name =="df_45T2" or name =="df_45T3" \
    or name =="df_7AA" or name =="df_7BB" or name =="df_7CC" or name =="df_7Y":
        label_name="PAO8+1,5%ZDDP+0,005%CNT+6ppm Stadis (homogenizer)"
    elif name =="df_2AA" or name =="df_2BB" or name =="df_2CC" or name =="df_2Y":
        label_name="PAO8+0,005% C60-C70"
    elif name =="df_3AA" or name =="df_3BB" or name =="df_3CC" or name =="df_3Y":
        label_name="PAO8+6ppm Stadis"
    elif name =="df_4AA" or name =="df_4BB" or name =="df_4CC" or name =="df_4DD" or name =="df_4Y":
        label_name="PAO8+0,005% C60-C70+1,5%ZDDP"
    elif name =="df_6AA" or name =="df_6BB" or name =="df_6CC" or name =="df_6Y":
        label_name="PAO8+6ppm Stadis+1,5%ZDDP"
    else:
        label_name="other"
    return label_name



def srednia_z_zakresu(start,stop,data,color,**kwargs):
    df_temp = data.set_index("Time", drop = False).loc[start:stop, "Time":"Voltage"]
    df_temp.reset_index(drop=True,inplace=True)
    
    for i in range (0,len(df_temp.Time)):
        plt.plot(df_temp.Time[i],df_temp.Voltage.mean(),'_',color=color,**kwargs)
        
    label = "{:.0f}".format(df_temp.Voltage.mean())
    label1 =  "{:.0f}".format(df_temp.Voltage.std())
    plt.text(201, x1, label+" $\pm$ "+label1, verticalalignment='bottom', horizontalalignment='left',
        color=color, fontsize=16)
#     plt.annotate(label+" $\pm$ "+label1, # this is the text
#         (stop,df_temp.Voltage.mean()+200), # this is the point to label
#         textcoords="offset points", # how to position the text
#         xytext=(0,5), # distance from text to points (x,y)
#         ha='left', size=20) # horizontal alignment can be left, right or center

def scatter_plot(data,**kwargs):
    data_name = get_df_name(data)
    color=kwargs.get("color")
    mask = dict(marker='.', s=10)
    plt.scatter(data.Time,data.Voltage, label=data_name,**kwargs, **mask)
    plt.plot(data.Time,data.Voltage,label='_nolegend_',**kwargs)
    global x1
    x1 = x1-70
    srednia_z_zakresu(6,31,data,color)
    x1 = x1-800  
    srednia_z_zakresu(150,175,data,color)
    x1 = x1+800 
    applyPlotStyle(2)



# scatter_plot(df_1Y, alpha=0.7, zorder=1, color='red')
# scatter_plot(df_2Y, alpha=0.7, zorder=1, color='black')
# scatter_plot(df_3Y, alpha=0.7, zorder=1, color='blue')
# scatter_plot(df_4Y, alpha=0.7, zorder=2, color='black')
# scatter_plot(df_5Y, alpha=0.7, zorder=2, color='green')
scatter_plot(df_6Y, alpha=0.7, zorder=1, color='green')
scatter_plot(df_7Y, alpha=0.7, zorder=1, color='blue')

# scatter_plot(df_41Y, alpha=0.7, zorder=1, color='magenta')
# scatter_plot(df_43Y, alpha=0.7, zorder=1, color='green')


plt.title("PEEK Dural DCV",fontsize=18)
plt.tick_params(axis='both', which='major', labelsize=14)


# plt.savefig("PEEK Dural DCV avrage_3.png", bbox_inches='tight',dpi=300)
plt.show()

# %%
df_temp.Voltage.std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-03f4403d0a1f> in <module>
# ----> 1 df_temp.Voltage.std()
#
# NameError: name 'df_temp' is not defined
